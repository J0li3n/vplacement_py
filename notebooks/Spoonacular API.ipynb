# %%
import requests
import pandas as pd
import json
import os
from dotenv import load_dotenv

load_dotenv(dotenv_path='../vplacement/config/.env')
# Out:
# True

# %%
def get_input_recipe(url):
    """ 
    Function to retrieve the information about the input recipe.
  
    Parameters: 
    url (str): URL of the recipe of interest
  
    Returns: 
    JSON: Recipe characteristics
  
    """
    base_url = "https://api.spoonacular.com/recipes/extract"
    parameters = {"apiKey": os.getenv('API_KEY'), 
                  "url":url}
    response = requests.request("GET", base_url, params=parameters)
    response_json = response.json()
    return response_json

# %%
#response_json = get_input_recipe("https://www.mynewroots.org/site/2014/01/big-comfy-sweet-potato/")
#response_json = get_input_recipe("https://www.beefitswhatsfordinner.com/recipes/recipe/55558/classic-beef-meatloaf")
# response_json = get_input_recipe("https://www.simplyrecipes.com/recipes/tandoori_chicken/")
# response_json = get_input_recipe("https://www.foodandwine.com/recipes/mushroom-and-chicken-risotto") :(
response_json = get_input_recipe("https://www.ricardocuisine.com/en/recipes/5762-classic-beef-chili")

# %%
response_json
# Out:
# {'vegetarian': False,
#  'vegan': False,
#  'glutenFree': False,
#  'dairyFree': False,
#  'veryHealthy': False,
#  'cheap': False,
#  'veryPopular': False,
#  'sustainable': False,
#  'weightWatcherSmartPoints': 0,
#  'gaps': 'no',
#  'lowFodmap': False,
#  'ketogenic': False,
#  'whole30': False,
#  'preparationMinutes': 15,
#  'cookingMinutes': 60,
#  'sourceUrl': 'https://www.ricardocuisine.com/en/recipes/5762-classic-beef-chili',
#  'aggregateLikes': 0,
#  'spoonacularScore': 0.0,
#  'healthScore': 0.0,
#  'pricePerServing': 0.0,
#  'extendedIngredients': [{'id': 11282,
#    'aisle': 'Produce',
#    'image': 'brown-onion.png',
#    'consitency': 'solid',
#    'name': 'onion',
#    'original': '1 onion, finely chopped',
#    'originalString': '1 onion, finely chopped',
#    'originalName': 'onion, finely chopped',
#    'amount': 1.0,
#    'unit': '',
#    'meta': ['finely chopped'],
#    'metaInformation': ['finely chopped'],
#    'measures': {'us': {'amount': 1.0, 'unitShort': '', 'unitLong': ''},
#     'metric': {'amount': 1.0, 'unitShort': '', 'unitLong': ''}}},
#   {'id': 11979,
#    'aisle': 'Canned and Jarred;Produce;Ethnic Foods',
#    'image': 'jalapeno-pepper.png',
#    'consitency': 'solid',
#    'name': 'jalapeno pepper',
#    'original': '1 jalapeño pepper, seeded or not, finely chopped',
#    'originalString': '1 jalapeño pepper, seeded or not, finely chopped',
#    'originalName': 'jalapeño pepper, seeded or not, finely chopped',
#    'amount': 1.0,
#    'unit': '',
#    'meta': ['seeded', 'finely chopped'],
#    'metaInformation': ['seeded', 'finely chopped'],
#    'measures': {'us': {'amount': 1.0, 'unitShort': '', 'unitLong': ''},
#     'metric': {'amount': 1.0, 'unitShort': '', 'unitLong': ''}}},
#   {'id': 1001,
#    'aisle': 'Milk, Eggs, Other Dairy',
#    'image': 'butter-sliced.jpg',
#    'consitency': 'solid',
#    'name': 'butter',
#    'original': '2 tablespoons (30 ml) butter',
#    'originalString': '2 tablespoons (30 ml) butter',
#    'originalName': 'tablespoons butter',
#    'amount': 30.0,
#    'unit': 'ml',
#    'meta': [],
#    'metaInformation': [],
#    'measures': {'us': {'amount': 1.015,
#      'unitShort': 'fl. oz',
#      'unitLong': 'fl. oz'},
#     'metric': {'amount': 30.0, 'unitShort': 'ml', 'unitLong': 'milliliters'}}},
#   {'id': 10023572,
#    'aisle': 'Meat',
#    'image': 'fresh-ground-beef.jpg',
#    'consitency': 'solid',
#    'name': 'ground beef',
#    'original': '2 lbs (1 kg) ground beef',
#    'originalString': '2 lbs (1 kg) ground beef',
#    'originalName': 'lbs ground beef',
#    'amount': 1.0,
#    'unit': 'kg',
#    'meta': [],
#    'metaInformation': [],
#    'measures': {'us': {'amount': 2.205,
#      'unitShort': 'lb',
#      'unitLong': 'pounds'},
#     'metric': {'amount': 1.0, 'unitShort': 'kg', 'unitLong': 'kg'}}},
#   {'id': 11215,
#    'aisle': 'Produce',
#    'image': 'garlic.png',
#    'consitency': 'solid',
#    'name': 'garlic',
#    'original': '2 cloves garlic, finely chopped',
#    'originalString': '2 cloves garlic, finely chopped',
#    'originalName': 'garlic, finely chopped',
#    'amount': 2.0,
#    'unit': 'cloves',
#    'meta': ['finely chopped'],
#    'metaInformation': ['finely chopped'],
#    'measures': {'us': {'amount': 2.0,
#      'unitShort': 'cloves',
#      'unitLong': 'cloves'},
#     'metric': {'amount': 2.0, 'unitShort': 'cloves', 'unitLong': 'cloves'}}},
#   {'id': 2009,
#    'aisle': 'Spices and Seasonings',
#    'image': 'chili-powder.jpg',
#    'consitency': 'solid',
#    'name': 'chili powder',
#    'original': '2 tablespoons (30 ml) chili powder',
#    'originalString': '2 tablespoons (30 ml) chili powder',
#    'originalName': 'tablespoons chili powder',
#    'amount': 30.0,
#    'unit': 'ml',
#    'meta': [],
#    'metaInformation': [],
#    'measures': {'us': {'amount': 1.015,
#      'unitShort': 'fl. oz',
#      'unitLong': 'fl. oz'},
#     'metric': {'amount': 30.0, 'unitShort': 'ml', 'unitLong': 'milliliters'}}},
#   {'id': 1002014,
#    'aisle': 'Spices and Seasonings',
#    'image': 'ground-cumin.jpg',
#    'consitency': 'solid',
#    'name': 'ground cumin',
#    'original': '1 teaspoon (5 ml) ground cumin',
#    'originalString': '1 teaspoon (5 ml) ground cumin',
#    'originalName': 'teaspoon ground cumin',
#    'amount': 5.0,
#    'unit': 'ml',
#    'meta': [],
#    'metaInformation': [],
#    'measures': {'us': {'amount': 0.169,
#      'unitShort': 'fl. oz',
#      'unitLong': 'fl. ozs'},
#     'metric': {'amount': 5.0, 'unitShort': 'ml', 'unitLong': 'milliliters'}}},
#   {'id': 10011693,
#    'aisle': 'Canned and Jarred',
#    'image': 'tomatoes-canned.png',
#    'consitency': 'solid',
#    'name': 'canned tomatoes',
#    'original': '1 can 28 oz (798 ml) diced tomatoes',
#    'originalString': '1 can 28 oz (798 ml) diced tomatoes',
#    'originalName': 'can 28 oz diced tomatoes',
#    'amount': 798.0,
#    'unit': 'ml',
#    'meta': ['diced', 'canned'],
#    'metaInformation': ['diced', 'canned'],
#    'measures': {'us': {'amount': 3.373,
#      'unitShort': 'cups',
#      'unitLong': 'cups'},
#     'metric': {'amount': 798.0,
#      'unitShort': 'ml',
#      'unitLong': 'milliliters'}}},
#   {'id': 16033,
#    'aisle': 'Pasta and Rice;Canned and Jarred',
#    'image': 'kidney-beans.jpg',
#    'consitency': 'solid',
#    'name': 'kidney beans',
#    'original': '1 can 19 oz (540 ml) kidney beans, rinsed and drained',
#    'originalString': '1 can 19 oz (540 ml) kidney beans, rinsed and drained',
#    'originalName': 'can 19 oz kidney beans, rinsed and drained',
#    'amount': 540.0,
#    'unit': 'ml',
#    'meta': ['rinsed', 'drained', 'canned'],
#    'metaInformation': ['rinsed', 'drained', 'canned'],
#    'measures': {'us': {'amount': 2.282,
#      'unitShort': 'cups',
#      'unitLong': 'cups'},
#     'metric': {'amount': 540.0,
#      'unitShort': 'ml',
#      'unitLong': 'milliliters'}}},
#   {'id': 14209,
#    'aisle': 'Tea and Coffee',
#    'image': 'brewed-coffee.jpg',
#    'consitency': 'solid',
#    'name': 'strong coffee',
#    'original': '1 cup (250 ml) regular or strong coffee',
#    'originalString': '1 cup (250 ml) regular or strong coffee',
#    'originalName': 'cup regular or strong coffee',
#    'amount': 250.0,
#    'unit': 'ml',
#    'meta': [],
#    'metaInformation': [],
#    'measures': {'us': {'amount': 1.057,
#      'unitShort': 'cups',
#      'unitLong': 'cups'},
#     'metric': {'amount': 250.0,
#      'unitShort': 'ml',
#      'unitLong': 'milliliters'}}},
#   {'id': 6008,
#    'aisle': 'Canned and Jarred',
#    'image': 'beef-broth.png',
#    'consitency': 'liquid',
#    'name': 'beef broth',
#    'original': '1/4 cup (60 ml) beef broth or water',
#    'originalString': '1/4 cup (60 ml) beef broth or water',
#    'originalName': '1/4 cup beef broth or water',
#    'amount': 60.0,
#    'unit': 'ml',
#    'meta': [],
#    'metaInformation': [],
#    'measures': {'us': {'amount': 2.029,
#      'unitShort': 'fl. oz',
#      'unitLong': 'fl. ozs'},
#     'metric': {'amount': 60.0, 'unitShort': 'ml', 'unitLong': 'milliliters'}}},
#   {'id': 11935,
#    'aisle': 'Condiments',
#    'image': 'ketchup.png',
#    'consitency': 'liquid',
#    'name': 'ketchup',
#    'original': '1/4 cup (60 ml) ketchup',
#    'originalString': '1/4 cup (60 ml) ketchup',
#    'originalName': '1/4 cup ketchup',
#    'amount': 60.0,
#    'unit': 'ml',
#    'meta': [],
#    'metaInformation': [],
#    'measures': {'us': {'amount': 2.029,
#      'unitShort': 'fl. oz',
#      'unitLong': 'fl. ozs'},
#     'metric': {'amount': 60.0, 'unitShort': 'ml', 'unitLong': 'milliliters'}}},
#   {'id': 9160,
#    'aisle': 'Produce',
#    'image': 'lime-juice.png',
#    'consitency': 'liquid',
#    'name': 'lime juice',
#    'original': '3 tablespoons (45 ml) lime juice',
#    'originalString': '3 tablespoons (45 ml) lime juice',
#    'originalName': 'tablespoons lime juice',
#    'amount': 45.0,
#    'unit': 'ml',
#    'meta': [],
#    'metaInformation': [],
#    'measures': {'us': {'amount': 1.522,
#      'unitShort': 'fl. oz',
#      'unitLong': 'fl. ozs'},
#     'metric': {'amount': 45.0, 'unitShort': 'ml', 'unitLong': 'milliliters'}}},
#   {'id': 11165,
#    'aisle': 'Produce',
#    'image': 'cilantro.png',
#    'consitency': 'solid',
#    'name': 'fresh cilantro',
#    'original': '1/4 cup (10 g) chopped fresh cilantro',
#    'originalString': '1/4 cup (10 g) chopped fresh cilantro',
#    'originalName': '1/4 cup chopped fresh cilantro',
#    'amount': 10.0,
#    'unit': 'g',
#    'meta': ['fresh', 'chopped'],
#    'metaInformation': ['fresh', 'chopped'],
#    'measures': {'us': {'amount': 0.353,
#      'unitShort': 'oz',
#      'unitLong': 'ounces'},
#     'metric': {'amount': 10.0, 'unitShort': 'g', 'unitLong': 'grams'}}}],
#  'id': -1,
#  'title': 'Classic Beef Chili',
#  'readyInMinutes': 75,
#  'servings': 6,
#  'image': 'https://images.ricardocuisine.com/services/recipes/600x-_5762.jpg',
#  'imageType': 'jpg',
#  'cuisines': [],
#  'dishTypes': [],
#  'diets': [],
#  'occasions': [],
#  'winePairing': {},
#  'instructions': None,
#  'analyzedInstructions': [],
#  'sourceName': None,
#  'creditsText': None}

# %%
def transform_to_ingredients(json):
    # Get ingredients
    ingredients = response_json['extendedIngredients']

    # Create dataframe
    df = pd.DataFrame(ingredients)
    # Exclude meat from dataframe
    df = df[df['aisle'] != 'Meat']
    df = df[-((df['name'].str.contains('meat')) |
              (df['name'].str.contains('beef')) |
              (df['name'].str.contains('chicken')))]

    ingredients_list = df['name'].tolist()

    ingredients_str = ','.join(ingredients_list)
    return ingredients_str

# %%
ingredients_str = transform_to_ingredients(response_json)

# %%
ingredients_str
# Out:
# 'onion,jalapeno pepper,butter,garlic,chili powder,ground cumin,canned tomatoes,kidney beans,strong coffee,ketchup,lime juice,fresh cilantro'

# %%
def get_output_recipes(ingredients, number=20, ranking=1, ignore_pantry=True):
    """
    Function return output recipe based on original ingredients

    Parameters:
    ingredients (str): ingredients of the recipe

    Returns:
    JSON: Recipes
    """
    base_url = "https://api.spoonacular.com/recipes/findByIngredients"
    parameters = {"apiKey": os.getenv('API_KEY'),
                  "ingredients": ingredients,
                  "number": number,
                  "ranking": ranking,
                  "ignorePantry": ignore_pantry,
                  }
    response = requests.request("GET", base_url, params=parameters)
    
    output_recipes = response.json()
    return output_recipes

# %%
output_recipes = get_output_recipes(ingredients_str)

# %%
def remove_meat_recipes(output_recipes):
    result = []
    result_ids = []
    meat_words = ['chicken', 'beef', 'meat']
    output_recipes_veg = []
    for recipe in range(0, len(output_recipes)):
        for ingredient in range(0, len(output_recipes[recipe]['missedIngredients'])):
            # Only continue when the recipe is not already found to have meat
            if output_recipes[recipe]['id'] not in (result_ids):
                # Add recipe id to list if the recipe contains meat or seafood
                if ((output_recipes[recipe]['missedIngredients'][ingredient]['aisle'] == 'Meat') |
                        (output_recipes[recipe]['missedIngredients'][ingredient]['aisle'] == 'Seafood') |
                        any(word in output_recipes[recipe]['missedIngredients'][ingredient]['name']
                            for word in meat_words)):
                    result.append(output_recipes[recipe])
                    result_ids.append(output_recipes[recipe]['id'])
        if output_recipes[recipe]['id'] not in (result_ids):
            output_recipes_veg.append(output_recipes[recipe])
    #output_recipes_veg = json.dumps({"output_recipes": output_recipes_veg})
    #output_recipes_veg = json.loads(output_recipes_veg)
    return output_recipes_veg

# %%
len(remove_meat_recipes(output_recipes))
# Out:
# 7

# %%
output_recipes_veg = remove_meat_recipes(output_recipes)

# %%
def remove_allergies(output_recipes_veg, allergies):
    result = []
    result_ids = []
    allergy_free_recipes = []
    allergy_list = allergies.split(', ')
    for recipe in range(0, len(output_recipes_veg)):
        for ingredient in range(0, len(output_recipes_veg[recipe]['missedIngredients'])):
            # Only continue when the recipe is not already found to have an allergy ingredient
            if output_recipes_veg[recipe]['id'] not in result_ids:
                # Add recipe id to list if the recipe contains an allergy ingredient
                if any(word in output_recipes_veg[recipe]['missedIngredients'][ingredient]['name']
                       for word in allergy_list):
                    result.append(output_recipes_veg[recipe])
                    result_ids.append(output_recipes_veg[recipe]['id'])
        if output_recipes_veg[recipe]['id'] not in result_ids:
            allergy_free_recipes.append(output_recipes_veg[recipe])
        output_recipes_veg = allergy_free_recipes
#     #allergy_free_recipes = json.dumps({"output_recipes": allergy_free_recipes})
#     #output_recipes_veg = json.loads(allergy_free_recipes)
    return output_recipes_veg

# %%
remove_allergies(output_recipes_veg, 'onion')
# Out:
# [{'id': 145288,
#   'title': 'My Salsa',
#   'image': 'https://spoonacular.com/recipeImages/145288-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 7,
#   'missedIngredientCount': 1,
#   'missedIngredients': [{'id': 10511282,
#     'amount': 0.5,
#     'unit': 'cup',
#     'unitLong': 'cups',
#     'unitShort': 'cup',
#     'aisle': 'Produce',
#     'name': 'yellow onion',
#     'original': '1/2 cup sweet yellow onion, roughly chopped',
#     'originalString': '1/2 cup sweet yellow onion, roughly chopped',
#     'originalName': 'sweet yellow onion, roughly chopped',
#     'metaInformation': ['sweet', 'yellow', 'roughly chopped'],
#     'extendedName': 'sweet yellow onion',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/brown-onion.png'}],
#   'usedIngredients': [{'id': 10011693,
#     'amount': 28.0,
#     'unit': 'ounce',
#     'unitLong': 'ounces',
#     'unitShort': 'oz',
#     'aisle': 'Canned and Jarred',
#     'name': 'canned tomatoes',
#     'original': '1 (28 ounce) can diced tomatoes',
#     'originalString': '1 (28 ounce) can diced tomatoes',
#     'originalName': 'diced tomatoes',
#     'metaInformation': ['diced', 'canned'],
#     'extendedName': 'diced canned tomatoes',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/tomatoes-canned.png'},
#    {'id': 2009,
#     'amount': 1.0,
#     'unit': 'teaspoon',
#     'unitLong': 'teaspoon',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'chili powder',
#     'original': '1 teaspoon chili powder',
#     'originalString': '1 teaspoon chili powder',
#     'originalName': 'chili powder',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/chili-powder.jpg'},
#    {'id': 1002014,
#     'amount': 1.0,
#     'unit': 'teaspoon',
#     'unitLong': 'teaspoon',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'cumin',
#     'original': '1 teaspoon cumin',
#     'originalString': '1 teaspoon cumin',
#     'originalName': 'cumin',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/ground-cumin.jpg'},
#    {'id': 11165,
#     'amount': 2.0,
#     'unit': 'tablespoons',
#     'unitLong': 'tablespoons',
#     'unitShort': 'Tbsp',
#     'aisle': 'Produce;Spices and Seasonings',
#     'name': 'fresh cilantro leaves',
#     'original': '2 tablespoons fresh cilantro leaves, roughly chopped',
#     'originalString': '2 tablespoons fresh cilantro leaves, roughly chopped',
#     'originalName': 'fresh cilantro leaves, roughly chopped',
#     'metaInformation': ['fresh', 'roughly chopped'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/cilantro.png'},
#    {'id': 11215,
#     'amount': 1.0,
#     'unit': 'tablespoon',
#     'unitLong': 'tablespoon',
#     'unitShort': 'Tbsp',
#     'aisle': 'Produce',
#     'name': 'garlic',
#     'original': '1 tablespoon garlic, minced',
#     'originalString': '1 tablespoon garlic, minced',
#     'originalName': 'garlic, minced',
#     'metaInformation': ['minced'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/garlic.jpg'},
#    {'id': 11979,
#     'amount': 1.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Canned and Jarred;Produce;Ethnic Foods',
#     'name': 'jalapeno pepper',
#     'original': '1 jalapeno pepper',
#     'originalString': '1 jalapeno pepper',
#     'originalName': 'jalapeno pepper',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/jalapeno-pepper.png'},
#    {'id': 9160,
#     'amount': 2.0,
#     'unit': 'tablespoons',
#     'unitLong': 'tablespoons',
#     'unitShort': 'Tbsp',
#     'aisle': 'Produce',
#     'name': 'lime juice',
#     'original': '2 tablespoons lime juice',
#     'originalString': '2 tablespoons lime juice',
#     'originalName': 'lime juice',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/lime-juice.png'}],
#   'unusedIngredients': [{'id': 11282,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Produce',
#     'name': 'onion',
#     'original': 'onion',
#     'originalString': 'onion',
#     'originalName': 'onion',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/brown-onion.png'},
#    {'id': 1001,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Milk, Eggs, Other Dairy',
#     'name': 'butter',
#     'original': 'butter',
#     'originalString': 'butter',
#     'originalName': 'butter',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/butter-sliced.jpg'},
#    {'id': 16033,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Pasta and Rice;Canned and Jarred',
#     'name': 'kidney beans',
#     'original': 'kidney beans',
#     'originalString': 'kidney beans',
#     'originalName': 'kidney beans',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/kidney-beans.jpg'},
#    {'id': 14209,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Tea and Coffee',
#     'name': 'strong coffee',
#     'original': 'strong coffee',
#     'originalString': 'strong coffee',
#     'originalName': 'strong coffee',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/brewed-coffee.jpg'},
#    {'id': 11935,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Condiments',
#     'name': 'ketchup',
#     'original': 'ketchup',
#     'originalString': 'ketchup',
#     'originalName': 'ketchup',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/ketchup.png'}],
#   'likes': 0},
#  {'id': 865396,
#   'title': 'RESTAURANT-STYLE FIRE ROASTED SALSA',
#   'image': 'https://spoonacular.com/recipeImages/865396-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 7,
#   'missedIngredientCount': 3,
#   'missedIngredients': [{'id': 98849,
#     'amount': 28.0,
#     'unit': 'oz',
#     'unitLong': 'ounces',
#     'unitShort': 'oz',
#     'aisle': 'Canned and Jarred',
#     'name': 'canned fire roasted tomatoes',
#     'original': '2 (14 oz) cans fire roasted tomatoes (drain them if you prefer a thicker salsa)',
#     'originalString': '2 (14 oz) cans fire roasted tomatoes (drain them if you prefer a thicker salsa)',
#     'originalName': 'fire roasted tomatoes (drain them if you prefer a thicker salsa)',
#     'metaInformation': ['fire roasted',
#      'canned',
#      '(drain them if you prefer a thicker salsa)'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/tomatoes-canned.png'},
#    {'id': 31015,
#     'amount': 4.0,
#     'unit': 'oz',
#     'unitLong': 'ounces',
#     'unitShort': 'oz',
#     'aisle': 'Produce',
#     'name': 'green chilies',
#     'original': '1 (4oz.) can diced green chilies (drain them if you prefer a thicker salsa)',
#     'originalString': '1 (4oz.) can diced green chilies (drain them if you prefer a thicker salsa)',
#     'originalName': 'diced green chilies (drain them if you prefer a thicker salsa)',
#     'metaInformation': ['diced',
#      'green',
#      'canned',
#      '(drain them if you prefer a thicker salsa)'],
#     'extendedName': 'canned diced green chilies',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/chili-peppers-green.jpg'},
#    {'id': 2027,
#     'amount': 0.5,
#     'unit': 'teaspoon',
#     'unitLong': 'teaspoons',
#     'unitShort': 'tsp',
#     'aisle': 'Produce;Spices and Seasonings',
#     'name': 'oregano',
#     'original': '1/2 teaspoon oregano',
#     'originalString': '1/2 teaspoon oregano',
#     'originalName': 'oregano',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/oregano.jpg'}],
#   'usedIngredients': [{'id': 11979,
#     'amount': 1.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Canned and Jarred;Produce;Ethnic Foods',
#     'name': 'jalapeno',
#     'original': '1 Jalapeno, (stem + seeds removed if you want less heat)',
#     'originalString': '1 Jalapeno, (stem + seeds removed if you want less heat)',
#     'originalName': 'Jalapeno, (stem + seeds removed if you want less heat)',
#     'metaInformation': ['seeds removed if you want less heat)'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/jalapeno-pepper.png'},
#    {'id': 9160,
#     'amount': 10.5,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Produce',
#     'name': 'juice of lime',
#     'original': 'Juice of 1 lime (about 21/2 tablespoons)',
#     'originalString': 'Juice of 1 lime (about 21/2 tablespoons)',
#     'originalName': 'Juice of 1 lime (about',
#     'metaInformation': [],
#     'extendedName': 'lime (juice)',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/lime-juice.png'},
#    {'id': 11282,
#     'amount': 1.0,
#     'unit': 'small',
#     'unitLong': 'small',
#     'unitShort': 'small',
#     'aisle': 'Produce',
#     'name': 'onion',
#     'original': '1 small onion, cut into small chunks',
#     'originalString': '1 small onion, cut into small chunks',
#     'originalName': 'onion, cut into small chunks',
#     'metaInformation': ['cut into small chunks'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/brown-onion.png'},
#    {'id': 11165,
#     'amount': 1.0,
#     'unit': 'cup',
#     'unitLong': 'cup',
#     'unitShort': 'cup',
#     'aisle': 'Produce;Spices and Seasonings',
#     'name': 'cilantro',
#     'original': '1/2 bunch of cilantro (about 1 cup loosely-packed) fresh cilantro',
#     'originalString': '1/2 bunch of cilantro (about 1 cup loosely-packed) fresh cilantro',
#     'originalName': '1/2 bunch of cilantro (about loosely-packed) fresh cilantro',
#     'metaInformation': ['fresh', 'loosely-packed'],
#     'extendedName': 'fresh cilantro',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/cilantro.png'},
#    {'id': 11215,
#     'amount': 1.5,
#     'unit': 'tablespoon',
#     'unitLong': 'tablespoons',
#     'unitShort': 'Tbsp',
#     'aisle': 'Produce',
#     'name': 'garlic',
#     'original': '1 1/2 tablespoon garlic, minced (if using fresh, use 3 cloves garlic)',
#     'originalString': '1 1/2 tablespoon garlic, minced (if using fresh, use 3 cloves garlic)',
#     'originalName': 'garlic, minced (if using fresh, use 3 cloves garlic)',
#     'metaInformation': ['fresh', 'minced', '(if using , use 3 cloves garlic)'],
#     'extendedName': 'fresh garlic',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/garlic.jpg'},
#    {'id': 2009,
#     'amount': 1.0,
#     'unit': 'teaspoon',
#     'unitLong': 'teaspoon',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'chili powder',
#     'original': '1 teaspoon chili powder (or less to taste)',
#     'originalString': '1 teaspoon chili powder (or less to taste)',
#     'originalName': 'chili powder (or less to taste)',
#     'metaInformation': ['to taste', '(or less )'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/chili-powder.jpg'},
#    {'id': 1002014,
#     'amount': 1.5,
#     'unit': 'teaspoon',
#     'unitLong': 'teaspoons',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'cumin powder',
#     'original': '1 1/2 teaspoon cumin powder',
#     'originalString': '1 1/2 teaspoon cumin powder',
#     'originalName': 'cumin powder',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/ground-cumin.jpg'}],
#   'unusedIngredients': [{'id': 1001,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Milk, Eggs, Other Dairy',
#     'name': 'butter',
#     'original': 'butter',
#     'originalString': 'butter',
#     'originalName': 'butter',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/butter-sliced.jpg'},
#    {'id': 10011693,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Canned and Jarred',
#     'name': 'canned tomatoes',
#     'original': 'canned tomatoes',
#     'originalString': 'canned tomatoes',
#     'originalName': 'canned tomatoes',
#     'metaInformation': ['canned'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/tomatoes-canned.png'},
#    {'id': 16033,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Pasta and Rice;Canned and Jarred',
#     'name': 'kidney beans',
#     'original': 'kidney beans',
#     'originalString': 'kidney beans',
#     'originalName': 'kidney beans',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/kidney-beans.jpg'},
#    {'id': 14209,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Tea and Coffee',
#     'name': 'strong coffee',
#     'original': 'strong coffee',
#     'originalString': 'strong coffee',
#     'originalName': 'strong coffee',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/brewed-coffee.jpg'},
#    {'id': 11935,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Condiments',
#     'name': 'ketchup',
#     'original': 'ketchup',
#     'originalString': 'ketchup',
#     'originalName': 'ketchup',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/ketchup.png'}],
#   'likes': 300},
#  {'id': 543281,
#   'title': 'Restaurant Style Salsa',
#   'image': 'https://spoonacular.com/recipeImages/543281-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 7,
#   'missedIngredientCount': 3,
#   'missedIngredients': [{'id': 11291,
#     'amount': 2.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Produce',
#     'name': 'green onions',
#     'original': '2 green onions',
#     'originalString': '2 green onions',
#     'originalName': 'green onions',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/spring-onions.jpg'},
#    {'id': 10011282,
#     'amount': 0.3333333333333333,
#     'unit': 'cup',
#     'unitLong': 'cups',
#     'unitShort': 'cup',
#     'aisle': 'Produce',
#     'name': 'red onion',
#     'original': '1/3 cup chopped red onion',
#     'originalString': '1/3 cup chopped red onion',
#     'originalName': 'chopped red onion',
#     'metaInformation': ['red', 'chopped'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/red-onion.png'},
#    {'id': 10211529,
#     'amount': 1.25,
#     'unit': 'lbs',
#     'unitLong': 'pounds',
#     'unitShort': 'lb',
#     'aisle': 'Produce',
#     'name': 'roma tomatoes',
#     'original': '6 ripe Roma tomatoes (about 1 1/4 lbs), halved',
#     'originalString': '6 ripe Roma tomatoes (about 1 1/4 lbs), halved',
#     'originalName': 'ripe Roma tomatoes (about , halved',
#     'metaInformation': ['ripe', 'halved'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/roma-tomatoes.png'}],
#   'usedIngredients': [{'id': 10011693,
#     'amount': 14.5,
#     'unit': 'oz',
#     'unitLong': 'ounces',
#     'unitShort': 'oz',
#     'aisle': 'Canned and Jarred',
#     'name': 'canned tomatoes',
#     'original': '1 (14.5 oz) can petite diced tomatoes with green chilis, undrained',
#     'originalString': '1 (14.5 oz) can petite diced tomatoes with green chilis, undrained',
#     'originalName': 'petite diced tomatoes with green chilis, undrained',
#     'metaInformation': ['diced', 'with green chilis, undrained', 'canned'],
#     'extendedName': 'diced canned tomatoes',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/tomatoes-canned.png'},
#    {'id': 2009,
#     'amount': 0.5,
#     'unit': 'tsp',
#     'unitLong': 'teaspoons',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'chili powder',
#     'original': '1/2 tsp chili powder',
#     'originalString': '1/2 tsp chili powder',
#     'originalName': 'chili powder',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/chili-powder.jpg'},
#    {'id': 11165,
#     'amount': 0.3333333333333333,
#     'unit': 'cup',
#     'unitLong': 'cups',
#     'unitShort': 'cup',
#     'aisle': 'Produce;Spices and Seasonings',
#     'name': 'fresh cilantro',
#     'original': '1/3 cup fresh cilantro (about a handful)',
#     'originalString': '1/3 cup fresh cilantro (about a handful)',
#     'originalName': 'fresh cilantro (about a handful)',
#     'metaInformation': ['fresh', '( a handful)'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/cilantro.png'},
#    {'id': 11215,
#     'amount': 1.0,
#     'unit': 'large clove',
#     'unitLong': 'large clove',
#     'unitShort': 'large clove',
#     'aisle': 'Produce',
#     'name': 'garlic',
#     'original': '1 large clove garlic, sliced',
#     'originalString': '1 large clove garlic, sliced',
#     'originalName': 'garlic, sliced',
#     'metaInformation': ['sliced'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/garlic.jpg'},
#    {'id': 1002014,
#     'amount': 0.25,
#     'unit': 'tsp',
#     'unitLong': 'teaspoons',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'ground cumin',
#     'original': '1/4 tsp ground cumin',
#     'originalString': '1/4 tsp ground cumin',
#     'originalName': 'ground cumin',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/ground-cumin.jpg'},
#    {'id': 11979,
#     'amount': 1.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Canned and Jarred;Produce;Ethnic Foods',
#     'name': 'jalapeno pepper',
#     'original': '1 jalapeno pepper, sliced into 5 pieces, stem removed*',
#     'originalString': '1 jalapeno pepper, sliced into 5 pieces, stem removed*',
#     'originalName': 'jalapeno pepper, sliced into 5 pieces, stem removed*',
#     'metaInformation': ['sliced into 5 pieces, stem removed*'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/jalapeno-pepper.png'},
#    {'id': 9160,
#     'amount': 2.0,
#     'unit': 'Tbsp',
#     'unitLong': 'Tbsps',
#     'unitShort': 'Tbsp',
#     'aisle': 'Produce',
#     'name': 'lime juice',
#     'original': '2 Tbsp fresh lime juice (from 1 large lime)',
#     'originalString': '2 Tbsp fresh lime juice (from 1 large lime)',
#     'originalName': 'fresh lime juice (from 1 large lime)',
#     'metaInformation': ['fresh', '(from 1 large lime)'],
#     'extendedName': 'fresh lime juice',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/lime-juice.png'}],
#   'unusedIngredients': [{'id': 11282,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Produce',
#     'name': 'onion',
#     'original': 'onion',
#     'originalString': 'onion',
#     'originalName': 'onion',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/brown-onion.png'},
#    {'id': 1001,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Milk, Eggs, Other Dairy',
#     'name': 'butter',
#     'original': 'butter',
#     'originalString': 'butter',
#     'originalName': 'butter',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/butter-sliced.jpg'},
#    {'id': 16033,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Pasta and Rice;Canned and Jarred',
#     'name': 'kidney beans',
#     'original': 'kidney beans',
#     'originalString': 'kidney beans',
#     'originalName': 'kidney beans',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/kidney-beans.jpg'},
#    {'id': 14209,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Tea and Coffee',
#     'name': 'strong coffee',
#     'original': 'strong coffee',
#     'originalString': 'strong coffee',
#     'originalName': 'strong coffee',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/brewed-coffee.jpg'},
#    {'id': 11935,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Condiments',
#     'name': 'ketchup',
#     'original': 'ketchup',
#     'originalString': 'ketchup',
#     'originalName': 'ketchup',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/ketchup.png'}],
#   'likes': 80},
#  {'id': 1022506,
#   'title': 'Fresh Homemade Salsa',
#   'image': 'https://spoonacular.com/recipeImages/1022506-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 7,
#   'missedIngredientCount': 3,
#   'missedIngredients': [{'id': 11291,
#     'amount': 2.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Produce',
#     'name': 'green onions',
#     'original': '2 green onions, ends trimmed, chopped into thirds',
#     'originalString': '2 green onions, ends trimmed, chopped into thirds',
#     'originalName': 'green onions, ends trimmed, chopped into thirds',
#     'metaInformation': ['ends trimmed', 'chopped'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/spring-onions.jpg'},
#    {'id': 10011282,
#     'amount': 0.3333333333333333,
#     'unit': 'cup',
#     'unitLong': 'cups',
#     'unitShort': 'cup',
#     'aisle': 'Produce',
#     'name': 'red onion',
#     'original': '1/3 cup chopped red onion (about 1/4 of a medium)',
#     'originalString': '1/3 cup chopped red onion (about 1/4 of a medium)',
#     'originalName': 'chopped red onion (about 1/4 of a medium)',
#     'metaInformation': ['red', 'chopped', '()'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/red-onion.png'},
#    {'id': 10211529,
#     'amount': 1.25,
#     'unit': 'lbs',
#     'unitLong': 'pounds',
#     'unitShort': 'lb',
#     'aisle': 'Produce',
#     'name': 'roma tomatoes',
#     'original': '1 1/4 lbs ripe Roma tomatoes (about 5 - 6)',
#     'originalString': '1 1/4 lbs ripe Roma tomatoes (about 5 - 6)',
#     'originalName': 'ripe Roma tomatoes (about 5 - 6)',
#     'metaInformation': ['ripe', '( 5 - 6)'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/roma-tomatoes.png'}],
#   'usedIngredients': [{'id': 10011693,
#     'amount': 14.5,
#     'unit': 'oz',
#     'unitLong': 'ounces',
#     'unitShort': 'oz',
#     'aisle': 'Canned and Jarred',
#     'name': 'canned tomatoes',
#     'original': '1 (14.5 oz) can petite diced tomatoes*',
#     'originalString': '1 (14.5 oz) can petite diced tomatoes*',
#     'originalName': 'petite diced tomatoes*',
#     'metaInformation': ['diced', 'canned'],
#     'extendedName': 'diced canned tomatoes',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/tomatoes-canned.png'},
#    {'id': 2009,
#     'amount': 0.5,
#     'unit': 'tsp',
#     'unitLong': 'teaspoons',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'chili powder',
#     'original': '1/2 tsp chili powder',
#     'originalString': '1/2 tsp chili powder',
#     'originalName': 'chili powder',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/chili-powder.jpg'},
#    {'id': 11165,
#     'amount': 0.3333333333333333,
#     'unit': 'cup',
#     'unitLong': 'cups',
#     'unitShort': 'cup',
#     'aisle': 'Produce;Spices and Seasonings',
#     'name': 'fresh cilantro',
#     'original': '1/3 cup fresh cilantro (about a handful)',
#     'originalString': '1/3 cup fresh cilantro (about a handful)',
#     'originalName': 'fresh cilantro (about a handful)',
#     'metaInformation': ['fresh', '( a handful)'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/cilantro.png'},
#    {'id': 11215,
#     'amount': 1.0,
#     'unit': 'large clove',
#     'unitLong': 'large clove',
#     'unitShort': 'large clove',
#     'aisle': 'Produce',
#     'name': 'garlic',
#     'original': '1 large clove garlic, roughly chopped',
#     'originalString': '1 large clove garlic, roughly chopped',
#     'originalName': 'garlic, roughly chopped',
#     'metaInformation': ['roughly chopped'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/garlic.jpg'},
#    {'id': 1002014,
#     'amount': 0.25,
#     'unit': 'tsp',
#     'unitLong': 'teaspoons',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'ground cumin',
#     'original': '1/4 tsp ground cumin',
#     'originalString': '1/4 tsp ground cumin',
#     'originalName': 'ground cumin',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/ground-cumin.jpg'},
#    {'id': 11979,
#     'amount': 1.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Canned and Jarred;Produce;Ethnic Foods',
#     'name': 'jalapeno pepper',
#     'original': '1 jalapeno pepper, seeded and roughly chopped',
#     'originalString': '1 jalapeno pepper, seeded and roughly chopped',
#     'originalName': 'jalapeno pepper, seeded and roughly chopped',
#     'metaInformation': ['seeded', 'roughly chopped'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/jalapeno-pepper.png'},
#    {'id': 9160,
#     'amount': 2.0,
#     'unit': 'Tbsp',
#     'unitLong': 'Tbsps',
#     'unitShort': 'Tbsp',
#     'aisle': 'Produce',
#     'name': 'lime juice',
#     'original': '2 Tbsp fresh lime juice',
#     'originalString': '2 Tbsp fresh lime juice',
#     'originalName': 'fresh lime juice',
#     'metaInformation': ['fresh'],
#     'extendedName': 'fresh lime juice',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/lime-juice.png'}],
#   'unusedIngredients': [{'id': 11282,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Produce',
#     'name': 'onion',
#     'original': 'onion',
#     'originalString': 'onion',
#     'originalName': 'onion',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/brown-onion.png'},
#    {'id': 1001,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Milk, Eggs, Other Dairy',
#     'name': 'butter',
#     'original': 'butter',
#     'originalString': 'butter',
#     'originalName': 'butter',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/butter-sliced.jpg'},
#    {'id': 16033,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Pasta and Rice;Canned and Jarred',
#     'name': 'kidney beans',
#     'original': 'kidney beans',
#     'originalString': 'kidney beans',
#     'originalName': 'kidney beans',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/kidney-beans.jpg'},
#    {'id': 14209,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Tea and Coffee',
#     'name': 'strong coffee',
#     'original': 'strong coffee',
#     'originalString': 'strong coffee',
#     'originalName': 'strong coffee',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/brewed-coffee.jpg'},
#    {'id': 11935,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Condiments',
#     'name': 'ketchup',
#     'original': 'ketchup',
#     'originalString': 'ketchup',
#     'originalName': 'ketchup',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/ketchup.png'}],
#   'likes': 1},
#  {'id': 80624,
#   'title': 'Spicy Salsa',
#   'image': 'https://spoonacular.com/recipeImages/80624-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 7,
#   'missedIngredientCount': 4,
#   'missedIngredients': [{'id': 2031,
#     'amount': 0.5,
#     'unit': 'tsp',
#     'unitLong': 'teaspoons',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'cayenne pepper',
#     'original': '1/2 tsp cayenne pepper',
#     'originalString': '1/2 tsp cayenne pepper',
#     'originalName': 'cayenne pepper',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/chili-powder.jpg'},
#    {'id': 1032009,
#     'amount': 0.75,
#     'unit': 'tsp',
#     'unitLong': 'teaspoons',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'red pepper flakes',
#     'original': '3/4 tsp crushed red pepper flakes',
#     'originalString': '3/4 tsp crushed red pepper flakes',
#     'originalName': 'crushed red pepper flakes',
#     'metaInformation': ['red', 'crushed'],
#     'extendedName': 'crushed red pepper flakes',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/red-pepper-flakes.jpg'},
#    {'id': 1016168,
#     'amount': 1.0,
#     'unit': 'Tbsp',
#     'unitLong': 'Tbsp',
#     'unitShort': 'Tbsp',
#     'aisle': 'Condiments',
#     'name': 'sriracha',
#     'original': '1 Tbsp Sriracha (or other hot chili sauce)',
#     'originalString': '1 Tbsp Sriracha (or other hot chili sauce)',
#     'originalName': 'Sriracha (or other hot chili sauce)',
#     'metaInformation': ['hot', '(or other chili sauce)'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/hot-sauce-or-tabasco.png'},
#    {'id': 11533,
#     'amount': 29.0,
#     'unit': 'oz',
#     'unitLong': 'ounces',
#     'unitShort': 'oz',
#     'aisle': 'Canned and Jarred',
#     'name': 'stewed tomatoes',
#     'original': '2 (14.5 oz) cans stewed tomatoes',
#     'originalString': '2 (14.5 oz) cans stewed tomatoes',
#     'originalName': 'stewed tomatoes',
#     'metaInformation': ['canned'],
#     'extendedName': 'canned stewed tomatoes',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/tomatoes-canned.png'}],
#   'usedIngredients': [{'id': 2009,
#     'amount': 0.75,
#     'unit': 'tsp',
#     'unitLong': 'teaspoons',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'chili powder',
#     'original': '3/4 tsp chili powder',
#     'originalString': '3/4 tsp chili powder',
#     'originalName': 'chili powder',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/chili-powder.jpg'},
#    {'id': 1002014,
#     'amount': 0.75,
#     'unit': 'tsp',
#     'unitLong': 'teaspoons',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'cumin',
#     'original': '3/4 tsp cumin',
#     'originalString': '3/4 tsp cumin',
#     'originalName': 'cumin',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/ground-cumin.jpg'},
#    {'id': 11165,
#     'amount': 3.0,
#     'unit': 'Tbsps',
#     'unitLong': 'Tbsps',
#     'unitShort': 'Tbsp',
#     'aisle': 'Produce;Spices and Seasonings',
#     'name': 'fresh cilantro',
#     'original': '3 Tbsps chopped fresh cilantro',
#     'originalString': '3 Tbsps chopped fresh cilantro',
#     'originalName': 'chopped fresh cilantro',
#     'metaInformation': ['fresh', 'chopped'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/cilantro.png'},
#    {'id': 11215,
#     'amount': 2.0,
#     'unit': 'cloves',
#     'unitLong': 'cloves',
#     'unitShort': 'cloves',
#     'aisle': 'Produce',
#     'name': 'garlic',
#     'original': '2 cloves of garlic',
#     'originalString': '2 cloves of garlic',
#     'originalName': 'garlic',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/garlic.jpg'},
#    {'id': 11979,
#     'amount': 2.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Canned and Jarred;Produce;Ethnic Foods',
#     'name': 'jalapenos',
#     'original': '2 fresh jalapeños; chopped and seeded',
#     'originalString': '2 fresh jalapeños; chopped and seeded',
#     'originalName': 'fresh jalapeños; chopped and seeded',
#     'metaInformation': ['fresh', 'seeded', 'chopped'],
#     'extendedName': 'fresh jalapenos',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/jalapeno-pepper.png'},
#    {'id': 9160,
#     'amount': 0.5,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Produce',
#     'name': 'juice of lime',
#     'original': '1/2 lime, juiced',
#     'originalString': '1/2 lime, juiced',
#     'originalName': 'lime, juiced',
#     'metaInformation': ['juiced'],
#     'extendedName': 'lime (juice)',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/lime-juice.png'},
#    {'id': 11282,
#     'amount': 0.5,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Produce',
#     'name': 'onion',
#     'original': '1/2 onion, finely diced',
#     'originalString': '1/2 onion, finely diced',
#     'originalName': 'onion, finely diced',
#     'metaInformation': ['diced', 'finely'],
#     'extendedName': 'diced onion',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/brown-onion.png'}],
#   'unusedIngredients': [{'id': 1001,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Milk, Eggs, Other Dairy',
#     'name': 'butter',
#     'original': 'butter',
#     'originalString': 'butter',
#     'originalName': 'butter',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/butter-sliced.jpg'},
#    {'id': 10011693,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Canned and Jarred',
#     'name': 'canned tomatoes',
#     'original': 'canned tomatoes',
#     'originalString': 'canned tomatoes',
#     'originalName': 'canned tomatoes',
#     'metaInformation': ['canned'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/tomatoes-canned.png'},
#    {'id': 16033,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Pasta and Rice;Canned and Jarred',
#     'name': 'kidney beans',
#     'original': 'kidney beans',
#     'originalString': 'kidney beans',
#     'originalName': 'kidney beans',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/kidney-beans.jpg'},
#    {'id': 14209,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Tea and Coffee',
#     'name': 'strong coffee',
#     'original': 'strong coffee',
#     'originalString': 'strong coffee',
#     'originalName': 'strong coffee',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/brewed-coffee.jpg'},
#    {'id': 11935,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Condiments',
#     'name': 'ketchup',
#     'original': 'ketchup',
#     'originalString': 'ketchup',
#     'originalName': 'ketchup',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/ketchup.png'}],
#   'likes': 5},
#  {'id': 528054,
#   'title': 'My Favorite Restaurant Style Salsa',
#   'image': 'https://spoonacular.com/recipeImages/528054-312x231.jpg',
#   'imageType': 'jpg',
#   'usedIngredientCount': 6,
#   'missedIngredientCount': 4,
#   'missedIngredients': [{'id': 93828,
#     'amount': 4.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Canned and Jarred',
#     'name': 'artichoke hearts',
#     'original': '4 quarters artichoke hearts, from a can',
#     'originalString': '4 quarters artichoke hearts, from a can',
#     'originalName': 'quarters artichoke hearts, from a can',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/artichoke-hearts.png'},
#    {'id': 11531,
#     'amount': 30.0,
#     'unit': 'oz',
#     'unitLong': 'ounces',
#     'unitShort': 'oz',
#     'aisle': 'Canned and Jarred',
#     'name': 'canned diced tomatoes',
#     'original': '2 (15 oz) cans diced tomatoes',
#     'originalString': '2 (15 oz) cans diced tomatoes',
#     'originalName': 'diced tomatoes',
#     'metaInformation': ['diced', 'canned'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/tomatoes-canned.png'},
#    {'id': 31015,
#     'amount': 4.0,
#     'unit': 'oz',
#     'unitLong': 'ounces',
#     'unitShort': 'oz',
#     'aisle': 'Produce',
#     'name': 'green chiles',
#     'original': '1 (4 oz) can diced green chiles',
#     'originalString': '1 (4 oz) can diced green chiles',
#     'originalName': 'diced green chiles',
#     'metaInformation': ['diced', 'green', 'canned'],
#     'extendedName': 'canned diced green chiles',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/chili-peppers-green.jpg'},
#    {'id': 10511282,
#     'amount': 0.5,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Produce',
#     'name': 'yellow onion',
#     'original': '1/2 yellow onion, peeled and roughly chopped',
#     'originalString': '1/2 yellow onion, peeled and roughly chopped',
#     'originalName': 'yellow onion, peeled and roughly chopped',
#     'metaInformation': ['yellow', 'peeled', 'roughly chopped'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/brown-onion.png'}],
#   'usedIngredients': [{'id': 2009,
#     'amount': 1.0,
#     'unit': 'teaspoon',
#     'unitLong': 'teaspoon',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'chili powder',
#     'original': '1 teaspoon chili powder',
#     'originalString': '1 teaspoon chili powder',
#     'originalName': 'chili powder',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/chili-powder.jpg'},
#    {'id': 11165,
#     'amount': 1.0,
#     'unit': 'leaves',
#     'unitLong': 'leave',
#     'unitShort': 'leaf',
#     'aisle': 'Produce;Spices and Seasonings',
#     'name': 'cilantro leaves',
#     'original': 'Small handful (about 1/4 cup loosely pack) cilantro leaves',
#     'originalString': 'Small handful (about 1/4 cup loosely pack) cilantro leaves',
#     'originalName': 'Small handful (about 1/4 cup loosely pack) cilantro',
#     'metaInformation': ['( 1/4 cup loosely pack)'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/cilantro.png'},
#    {'id': 1002014,
#     'amount': 1.0,
#     'unit': 'teaspoon',
#     'unitLong': 'teaspoon',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'cumin',
#     'original': '1 teaspoon cumin',
#     'originalString': '1 teaspoon cumin',
#     'originalName': 'cumin',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/ground-cumin.jpg'},
#    {'id': 11215,
#     'amount': 3.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Produce',
#     'name': 'garlic cloves',
#     'original': '3 garlic cloves, peeled and halved',
#     'originalString': '3 garlic cloves, peeled and halved',
#     'originalName': 'garlic cloves, peeled and halved',
#     'metaInformation': ['peeled', 'halved'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/garlic.jpg'},
#    {'id': 11979,
#     'amount': 2.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Canned and Jarred;Produce;Ethnic Foods',
#     'name': 'jalapeno peppers',
#     'original': '2 pickled jalapeño peppers from a can, chopped',
#     'originalString': '2 pickled jalapeño peppers from a can, chopped',
#     'originalName': 'pickled jalapeño peppers from a can, chopped',
#     'metaInformation': ['chopped'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/jalapeno-pepper.png'},
#    {'id': 9160,
#     'amount': 1.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Produce',
#     'name': 'juice of lime',
#     'original': 'Juice from 1 lime',
#     'originalString': 'Juice from 1 lime',
#     'originalName': 'Juice from lime',
#     'metaInformation': [],
#     'extendedName': 'lime (juice)',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/lime-juice.png'}],
#   'unusedIngredients': [{'id': 11282,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Produce',
#     'name': 'onion',
#     'original': 'onion',
#     'originalString': 'onion',
#     'originalName': 'onion',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/brown-onion.png'},
#    {'id': 1001,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Milk, Eggs, Other Dairy',
#     'name': 'butter',
#     'original': 'butter',
#     'originalString': 'butter',
#     'originalName': 'butter',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/butter-sliced.jpg'},
#    {'id': 10011693,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Canned and Jarred',
#     'name': 'canned tomatoes',
#     'original': 'canned tomatoes',
#     'originalString': 'canned tomatoes',
#     'originalName': 'canned tomatoes',
#     'metaInformation': ['canned'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/tomatoes-canned.png'},
#    {'id': 16033,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Pasta and Rice;Canned and Jarred',
#     'name': 'kidney beans',
#     'original': 'kidney beans',
#     'originalString': 'kidney beans',
#     'originalName': 'kidney beans',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/kidney-beans.jpg'},
#    {'id': 14209,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Tea and Coffee',
#     'name': 'strong coffee',
#     'original': 'strong coffee',
#     'originalString': 'strong coffee',
#     'originalName': 'strong coffee',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/brewed-coffee.jpg'},
#    {'id': 11935,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Condiments',
#     'name': 'ketchup',
#     'original': 'ketchup',
#     'originalString': 'ketchup',
#     'originalName': 'ketchup',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/ketchup.png'}],
#   'likes': 17},
#  {'id': 754996,
#   'title': 'Vegetable and Bean Chili',
#   'image': 'https://spoonacular.com/recipeImages/754996-312x231.jpeg',
#   'imageType': 'jpeg',
#   'usedIngredientCount': 6,
#   'missedIngredientCount': 5,
#   'missedIngredients': [{'id': 16034,
#     'amount': 60.0,
#     'unit': 'ounce',
#     'unitLong': 'ounces',
#     'unitShort': 'oz',
#     'aisle': 'Canned and Jarred',
#     'name': 'canned kidney beans',
#     'original': '4 (15-ounce) cans kidney beans, rinsed, drained',
#     'originalString': '4 (15-ounce) cans kidney beans, rinsed, drained',
#     'originalName': 'kidney beans, rinsed, drained',
#     'metaInformation': ['rinsed', 'drained', 'canned'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/kidney-beans.jpg'},
#    {'id': 10011531,
#     'amount': 56.0,
#     'unit': 'ounce',
#     'unitLong': 'ounces',
#     'unitShort': 'oz',
#     'aisle': 'Canned and Jarred',
#     'name': 'canned whole tomatoes',
#     'original': '2 (28-ounce) cans whole tomatoes, coarsely chopped, with juice',
#     'originalString': '2 (28-ounce) cans whole tomatoes, coarsely chopped, with juice',
#     'originalName': 'whole tomatoes, coarsely chopped, with juice',
#     'metaInformation': ['whole', 'with juice', 'coarsely chopped', 'canned'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/tomatoes-canned.png'},
#    {'id': 11333,
#     'amount': 2.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Produce',
#     'name': 'green bell peppers',
#     'original': '2 green bell peppers, cut into 1/2-inch pieces',
#     'originalString': '2 green bell peppers, cut into 1/2-inch pieces',
#     'originalName': 'green bell peppers, cut into 1/2-inch pieces',
#     'metaInformation': ['green', 'cut into 1/2-inch pieces'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/green-pepper.jpg'},
#    {'id': 19078,
#     'amount': 2.0,
#     'unit': 'tablespoons',
#     'unitLong': 'tablespoons',
#     'unitShort': 'Tbsp',
#     'aisle': 'Baking',
#     'name': 'unsweetened chocolate',
#     'original': '2 tablespoons chopped unsweetened chocolate',
#     'originalString': '2 tablespoons chopped unsweetened chocolate',
#     'originalName': 'chopped unsweetened chocolate',
#     'metaInformation': ['unsweetened', 'chopped'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/baking-chocolate.jpg'},
#    {'id': 11477,
#     'amount': 4.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Produce',
#     'name': 'zucchini',
#     'original': '4 zucchini, cut into 1/2-inch cubes',
#     'originalString': '4 zucchini, cut into 1/2-inch cubes',
#     'originalName': 'zucchini, cut into 1/2-inch cubes',
#     'metaInformation': ['cut into 1/2-inch cubes'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/zucchini.jpg'}],
#   'usedIngredients': [{'id': 2009,
#     'amount': 2.0,
#     'unit': 'tablespoons',
#     'unitLong': 'tablespoons',
#     'unitShort': 'Tbsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'chili powder',
#     'original': '2 tablespoons chili powder',
#     'originalString': '2 tablespoons chili powder',
#     'originalName': 'chili powder',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/chili-powder.jpg'},
#    {'id': 11165,
#     'amount': 0.3333333333333333,
#     'unit': 'cup',
#     'unitLong': 'cups',
#     'unitShort': 'cup',
#     'aisle': 'Produce;Spices and Seasonings',
#     'name': 'fresh cilantro leaves',
#     'original': '1/3 cup chopped fresh cilantro leaves',
#     'originalString': '1/3 cup chopped fresh cilantro leaves',
#     'originalName': 'chopped fresh cilantro leaves',
#     'metaInformation': ['fresh', 'chopped'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/cilantro.png'},
#    {'id': 11215,
#     'amount': 6.0,
#     'unit': 'large',
#     'unitLong': 'larges',
#     'unitShort': 'large',
#     'aisle': 'Produce',
#     'name': 'garlic cloves',
#     'original': '6 large garlic cloves, finely chopped',
#     'originalString': '6 large garlic cloves, finely chopped',
#     'originalName': 'garlic cloves, finely chopped',
#     'metaInformation': ['finely chopped'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/garlic.jpg'},
#    {'id': 1002014,
#     'amount': 2.0,
#     'unit': 'teaspoons',
#     'unitLong': 'teaspoons',
#     'unitShort': 'tsp',
#     'aisle': 'Spices and Seasonings',
#     'name': 'ground cumin',
#     'original': '2 teaspoons ground cumin',
#     'originalString': '2 teaspoons ground cumin',
#     'originalName': 'ground cumin',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/ground-cumin.jpg'},
#    {'id': 11979,
#     'amount': 1.0,
#     'unit': '',
#     'unitLong': '',
#     'unitShort': '',
#     'aisle': 'Canned and Jarred;Produce;Ethnic Foods',
#     'name': 'jalapeno chile',
#     'original': '1 fresh jalapeno chile, finely chopped (including seeds)',
#     'originalString': '1 fresh jalapeno chile, finely chopped (including seeds)',
#     'originalName': 'fresh jalapeno chile, finely chopped (including seeds)',
#     'metaInformation': ['fresh', 'finely chopped', '(including seeds)'],
#     'extendedName': 'fresh jalapeno chile',
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/jalapeno-pepper.png'},
#    {'id': 11282,
#     'amount': 1.0,
#     'unit': 'pound',
#     'unitLong': 'pound',
#     'unitShort': 'lb',
#     'aisle': 'Produce',
#     'name': 'onions',
#     'original': '4 large onions (1 pound), coarsely chopped',
#     'originalString': '4 large onions (1 pound), coarsely chopped',
#     'originalName': 'large onions , coarsely chopped',
#     'metaInformation': ['coarsely chopped'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/brown-onion.png'}],
#   'unusedIngredients': [{'id': 1001,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Milk, Eggs, Other Dairy',
#     'name': 'butter',
#     'original': 'butter',
#     'originalString': 'butter',
#     'originalName': 'butter',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/butter-sliced.jpg'},
#    {'id': 10011693,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Canned and Jarred',
#     'name': 'canned tomatoes',
#     'original': 'canned tomatoes',
#     'originalString': 'canned tomatoes',
#     'originalName': 'canned tomatoes',
#     'metaInformation': ['canned'],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/tomatoes-canned.png'},
#    {'id': 16033,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Pasta and Rice;Canned and Jarred',
#     'name': 'kidney beans',
#     'original': 'kidney beans',
#     'originalString': 'kidney beans',
#     'originalName': 'kidney beans',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/kidney-beans.jpg'},
#    {'id': 14209,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Tea and Coffee',
#     'name': 'strong coffee',
#     'original': 'strong coffee',
#     'originalString': 'strong coffee',
#     'originalName': 'strong coffee',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/brewed-coffee.jpg'},
#    {'id': 11935,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Condiments',
#     'name': 'ketchup',
#     'original': 'ketchup',
#     'originalString': 'ketchup',
#     'originalName': 'ketchup',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/ketchup.png'},
#    {'id': 9160,
#     'amount': 1.0,
#     'unit': 'serving',
#     'unitLong': 'serving',
#     'unitShort': 'serving',
#     'aisle': 'Produce',
#     'name': 'lime juice',
#     'original': 'lime juice',
#     'originalString': 'lime juice',
#     'originalName': 'lime juice',
#     'metaInformation': [],
#     'image': 'https://spoonacular.com/cdn/ingredients_100x100/lime-juice.png'}],
#   'likes': 19}]

# %%
allergies = 'tomato, peanut'

# %%
allergies_list = allergies.split(', ')

# %%
df = pd.DataFrame({"name":['peanut', 'melon', 'tomato']})

# %%
df
# Out:
#      name
# 0  peanut
# 1   melon
# 2  tomato

# %%
df[-((df['name'].str.contains("peanut")))]
# Out:
#      name
# 1   melon
# 2  tomato

# %%
df[-(df['name'].apply(lambda x: any(word in x for word in allergies_list)))]
# Out:
#     name
# 1  melon

# %%
for number in range(0,1):
    print(number)
# Out:
# 0

# %%
text=['tomato']

# %%
text.append('aha')

# %%
text
# Out:
# ['tomato', 'aha']

# %%
text[0]
# Out:
# 'tomato'

# %%
text[1]
# Out:
# 'aha'
